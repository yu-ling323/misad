# %%
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/misad')

# %%
! pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/misad

# %%
! git config --global user.email "huangyuling323@gmail.com"
! git config --global user.name "ylhuang"

# %%
#驗證上排
! git config --list
# Out:
# user.email=huangyuling323@gmail.com
# user.name=ylhuang
# core.repositoryformatversion=0
# core.filemode=true
# core.bare=false
# core.logallrefupdates=true
# core.symlinks=false

# %%
! git init
# Out:
# Initialized empty Git repository in /content/drive/My Drive/Colab Notebooks/misad/.git/

# %%
! git add -A
! git commit -m "first commit"
# Out:
# On branch master
#
# Initial commit
#
# nothing to commit

# %%
#下方帳號輸入錯誤，重新輸入
! git remote rm origin

# %%
! git remote add origin https://yu-ling323:Huang2019@github.com/yu-ling323/misad.git

# %%
! git log --oneline
# Out:
# fatal: your current branch 'master' does not have any commits yet

# %%
! git branch -M main
! git push -u origin main
# Out:
# error: refname refs/heads/master not found
# fatal: Branch rename failed
# error: src refspec main does not match any.
# error: failed to push some refs to 'https://yu-ling323:Huang2019@github.com/yu-ling323/misad.git'
